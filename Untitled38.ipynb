# %%
# ============================================================
# CODE 1
# GENERATE + SAVE FULL 300 x 300 SNAPSHOTS
#
# CASE:
#       E = W
#       N = S
#
# FULL UNIVERSE:
#       3000 x 3000
#
# ANALYTICAL SNAPSHOT:
#       CENTRAL 300 x 300
#
# RULES:
#       256
#
# TIME:
#       100
#
# SAVES:
#       Rule_000.npy ... Rule_255.npy
#
# EACH FILE:
#       shape = (100, 300, 300)
#
# NO MIDDLE ROW
# ============================================================

import numpy as np
import os
import gc
from tqdm import tqdm


# ============================================================
# PARAMETERS
# ============================================================

N_ROWS = 3000
N_COLS = 3000

CROP_ROWS = 300
CROP_COLS = 300

TIME_STEPS = 100
NUM_RULES = 256

OUTPUT_FOLDER = "CA_Snapshots_256"

os.makedirs(
    OUTPUT_FOLDER,
    exist_ok=True
)


# ============================================================
# CENTRAL 300 x 300 CROP
# ============================================================

r0 = (
    N_ROWS - CROP_ROWS
) // 2

r1 = r0 + CROP_ROWS

c0 = (
    N_COLS - CROP_COLS
) // 2

c1 = c0 + CROP_COLS


# ============================================================
# SAME INITIAL GRID FOR ALL RULES
# ============================================================

rng = np.random.default_rng(42)

initial_grid = rng.integers(
    0,
    2,
    size=(N_ROWS, N_COLS),
    dtype=np.uint8
)

print(
    "Initial grid:",
    initial_grid.shape
)


# ============================================================
# VALID RMTs
#
# ORDER:
#       N W C E S
#
# CONDITION:
#       N = S
#       E = W
# ============================================================

valid_rmts = []

for N in [0, 1]:

    for W in [0, 1]:

        for C in [0, 1]:

            for E in [0, 1]:

                for S in [0, 1]:

                    if N == S and E == W:

                        valid_rmts.append(
                            (N, W, C, E, S)
                        )


assert len(valid_rmts) == 8


# ============================================================
# GENERATE 256 RULES
#
# 8 VALID RMTs
# 24 OTHER RMTs = 0
# ============================================================

rmt_rules = []

for rule_number in range(
    NUM_RULES
):

    logical_rule = format(
        rule_number,
        "08b"
    )

    rule = np.zeros(
        32,
        dtype=np.uint8
    )

    for rmt, output in zip(
        valid_rmts,
        logical_rule
    ):

        N, W, C, E, S = rmt

        index = (
            (N << 4)
            |
            (W << 3)
            |
            (C << 2)
            |
            (E << 1)
            |
            S
        )

        rule[index] = int(output)

    rmt_rules.append(rule)


rmt_rules = np.array(
    rmt_rules,
    dtype=np.uint8
)


# ============================================================
# EVOLUTION
# ============================================================

def evolve(
    grid,
    rule
):

    N = np.roll(
        grid,
        1,
        axis=0
    )

    S = np.roll(
        grid,
        -1,
        axis=0
    )

    W = np.roll(
        grid,
        1,
        axis=1
    )

    E = np.roll(
        grid,
        -1,
        axis=1
    )

    index = (
        (N << 4)
        |
        (W << 3)
        |
        (grid << 2)
        |
        (E << 1)
        |
        S
    )

    new_grid = rule[index]

    del N, S, W, E, index

    return new_grid


# ============================================================
# PROCESS EACH RULE
# ============================================================

for rule_number in tqdm(
    range(NUM_RULES),
    desc="Generating rules"
):

    output_file = os.path.join(
        OUTPUT_FOLDER,
        f"Rule_{rule_number:03d}.npy"
    )


    # --------------------------------------------------------
    # RESUME SUPPORT
    # --------------------------------------------------------

    if os.path.exists(
        output_file
    ):

        print(
            f"Skipping Rule {rule_number} "
            "(already saved)"
        )

        continue


    grid = initial_grid.copy()


    # --------------------------------------------------------
    # STORE ONLY THE 300 x 300 SNAPSHOTS
    #
    # NOT the 3000 x 3000 grids
    # --------------------------------------------------------

    snapshots = np.empty(
        (
            TIME_STEPS,
            CROP_ROWS,
            CROP_COLS
        ),
        dtype=np.uint8
    )


    # ========================================================
    # 100 TIME STEPS
    # ========================================================

    for t in range(
        TIME_STEPS
    ):

        # FULL 300 x 300 SNAPSHOT
        snapshots[t] = grid[
            r0:r1,
            c0:c1
        ]


        # EVOLVE FULL 3000 x 3000 UNIVERSE
        grid = evolve(
            grid,
            rmt_rules[
                rule_number
            ]
        )


    # --------------------------------------------------------
    # SAVE:
    #
    # (100, 300, 300)
    # --------------------------------------------------------

    np.save(
        output_file,
        snapshots
    )


    print(
        f"Rule {rule_number} saved:",
        snapshots.shape
    )


    # --------------------------------------------------------
    # RELEASE MEMORY
    # --------------------------------------------------------

    del snapshots
    del grid

    gc.collect()


print("\n======================================")
print("CODE 1 COMPLETE")
print("======================================")
print(
    "Saved folder:",
    OUTPUT_FOLDER
)
print(
    "Each rule:",
    "(100, 300, 300)"
)
print(
    "Total rules:",
    NUM_RULES
)
# Out:
# Initial grid: (3000, 3000)
# Generating rules:   0%|          | 1/256 [00:05<22:29,  5.29s/it]
# Rule 0 saved: (100, 300, 300)
# Generating rules:   1%|          | 2/256 [00:11<23:27,  5.54s/it]
# Rule 1 saved: (100, 300, 300)
# Generating rules:   1%|          | 3/256 [00:16<22:22,  5.31s/it]
# Rule 2 saved: (100, 300, 300)
# Generating rules:   2%|▏         | 4/256 [00:22<23:23,  5.57s/it]
# Rule 3 saved: (100, 300, 300)
# Generating rules:   2%|▏         | 5/256 [00:27<22:35,  5.40s/it]
# Rule 4 saved: (100, 300, 300)
# Generating rules:   2%|▏         | 6/256 [00:32<22:50,  5.48s/it]
# Rule 5 saved: (100, 300, 300)
# Generating rules:   3%|▎         | 7/256 [00:38<22:34,  5.44s/it]
# Rule 6 saved: (100, 300, 300)
# Generating rules:   3%|▎         | 8/256 [00:43<21:59,  5.32s/it]
# Rule 7 saved: (100, 300, 300)
# Generating rules:   4%|▎         | 9/256 [00:49<22:43,  5.52s/it]
# Rule 8 saved: (100, 300, 300)
# Generating rules:   4%|▍         | 10/256 [00:54<21:59,  5.36s/it]
# Rule 9 saved: (100, 300, 300)
# Generating rules:   4%|▍         | 11/256 [01:00<22:41,  5.56s/it]
# Rule 10 saved: (100, 300, 300)
# Generating rules:   5%|▍         | 12/256 [01:05<21:57,  5.40s/it]
# Rule 11 saved: (100, 300, 300)
# Generating rules:   5%|▌         | 13/256 [01:10<21:25,  5.29s/it]
# Rule 12 saved: (100, 300, 300)
# Generating rules:   5%|▌         | 14/256 [01:16<22:10,  5.50s/it]
# Rule 13 saved: (100, 300, 300)
# Generating rules:   6%|▌         | 15/256 [01:21<21:31,  5.36s/it]
# Rule 14 saved: (100, 300, 300)
# Generating rules:   6%|▋         | 16/256 [01:27<22:15,  5.56s/it]
# Rule 15 saved: (100, 300, 300)
# Generating rules:   7%|▋         | 17/256 [01:32<21:32,  5.41s/it]
# Rule 16 saved: (100, 300, 300)
# Generating rules:   7%|▋         | 18/256 [01:37<21:26,  5.41s/it]
# Rule 17 saved: (100, 300, 300)
# Generating rules:   7%|▋         | 19/256 [01:43<21:34,  5.46s/it]
# Rule 18 saved: (100, 300, 300)
# Generating rules:   8%|▊         | 20/256 [01:48<21:01,  5.34s/it]
# Rule 19 saved: (100, 300, 300)
# Generating rules:   8%|▊         | 21/256 [01:54<21:41,  5.54s/it]
# Rule 20 saved: (100, 300, 300)
# Generating rules:   9%|▊         | 22/256 [01:59<20:59,  5.38s/it]
# Rule 21 saved: (100, 300, 300)
# Generating rules:   9%|▉         | 23/256 [02:05<21:20,  5.49s/it]
# Rule 22 saved: (100, 300, 300)
# Generating rules:   9%|▉         | 24/256 [02:10<20:57,  5.42s/it]
# Rule 23 saved: (100, 300, 300)
# Generating rules:  10%|▉         | 25/256 [02:15<20:22,  5.29s/it]
# Rule 24 saved: (100, 300, 300)
# Generating rules:  10%|█         | 26/256 [02:21<21:04,  5.50s/it]
# Rule 25 saved: (100, 300, 300)
# Generating rules:  11%|█         | 27/256 [02:26<20:23,  5.34s/it]
# Rule 26 saved: (100, 300, 300)
# Generating rules:  11%|█         | 28/256 [02:32<20:59,  5.53s/it]
# Rule 27 saved: (100, 300, 300)
# Generating rules:  11%|█▏        | 29/256 [02:37<20:19,  5.37s/it]
# Rule 28 saved: (100, 300, 300)
# Generating rules:  12%|█▏        | 30/256 [02:42<20:00,  5.31s/it]
# Rule 29 saved: (100, 300, 300)
# Generating rules:  12%|█▏        | 31/256 [02:48<20:28,  5.46s/it]
# Rule 30 saved: (100, 300, 300)
# Generating rules:  12%|█▎        | 32/256 [02:53<19:56,  5.34s/it]
# Rule 31 saved: (100, 300, 300)
# Generating rules:  13%|█▎        | 33/256 [02:59<20:31,  5.52s/it]
# Rule 32 saved: (100, 300, 300)
# Generating rules:  13%|█▎        | 34/256 [03:04<19:54,  5.38s/it]
# Rule 33 saved: (100, 300, 300)
# Generating rules:  14%|█▎        | 35/256 [03:09<19:57,  5.42s/it]
# Rule 34 saved: (100, 300, 300)
# Generating rules:  14%|█▍        | 36/256 [03:15<19:54,  5.43s/it]
# Rule 35 saved: (100, 300, 300)
# Generating rules:  14%|█▍        | 37/256 [03:20<19:40,  5.39s/it]
# Rule 36 saved: (100, 300, 300)
# Generating rules:  15%|█▍        | 38/256 [03:26<20:15,  5.57s/it]
# Rule 37 saved: (100, 300, 300)
# Generating rules:  15%|█▌        | 39/256 [03:31<19:34,  5.41s/it]
# Rule 38 saved: (100, 300, 300)
# Generating rules:  16%|█▌        | 40/256 [03:37<20:07,  5.59s/it]
# Rule 39 saved: (100, 300, 300)
# Generating rules:  16%|█▌        | 41/256 [03:43<19:50,  5.54s/it]
# Rule 40 saved: (100, 300, 300)
# Generating rules:  16%|█▋        | 42/256 [03:48<19:25,  5.45s/it]
# Rule 41 saved: (100, 300, 300)
# Generating rules:  17%|█▋        | 43/256 [03:54<19:36,  5.53s/it]
# Rule 42 saved: (100, 300, 300)
# Generating rules:  17%|█▋        | 44/256 [03:59<19:00,  5.38s/it]
# Rule 43 saved: (100, 300, 300)
# Generating rules:  18%|█▊        | 45/256 [04:04<19:29,  5.54s/it]
# Rule 44 saved: (100, 300, 300)
# Generating rules:  18%|█▊        | 46/256 [04:09<18:50,  5.38s/it]
# Rule 45 saved: (100, 300, 300)
# Generating rules:  18%|█▊        | 47/256 [04:15<18:56,  5.44s/it]
# Rule 46 saved: (100, 300, 300)
# Generating rules:  19%|█▉        | 48/256 [04:20<18:48,  5.43s/it]
# Rule 47 saved: (100, 300, 300)
# Generating rules:  19%|█▉        | 49/256 [04:25<18:13,  5.29s/it]
# Rule 48 saved: (100, 300, 300)
# Generating rules:  20%|█▉        | 50/256 [04:31<18:51,  5.49s/it]
# Rule 49 saved: (100, 300, 300)
# Generating rules:  20%|█▉        | 51/256 [04:36<18:18,  5.36s/it]
# Rule 50 saved: (100, 300, 300)
# Generating rules:  20%|██        | 52/256 [04:42<18:47,  5.53s/it]
# Rule 51 saved: (100, 300, 300)
# Generating rules:  21%|██        | 53/256 [04:47<18:19,  5.41s/it]
# Rule 52 saved: (100, 300, 300)
# Generating rules:  21%|██        | 54/256 [04:53<17:50,  5.30s/it]
# Rule 53 saved: (100, 300, 300)
# Generating rules:  21%|██▏       | 55/256 [04:59<18:28,  5.52s/it]
# Rule 54 saved: (100, 300, 300)
# Generating rules:  22%|██▏       | 56/256 [05:04<17:57,  5.39s/it]
# Rule 55 saved: (100, 300, 300)
# Generating rules:  22%|██▏       | 57/256 [05:10<18:26,  5.56s/it]
# Rule 56 saved: (100, 300, 300)
# Generating rules:  23%|██▎       | 58/256 [05:15<17:48,  5.40s/it]
# Rule 57 saved: (100, 300, 300)
# Generating rules:  23%|██▎       | 59/256 [05:20<17:45,  5.41s/it]
# Rule 58 saved: (100, 300, 300)
# Generating rules:  23%|██▎       | 60/256 [05:26<17:54,  5.48s/it]
# Rule 59 saved: (100, 300, 300)
# Generating rules:  24%|██▍       | 61/256 [05:31<17:21,  5.34s/it]
# Rule 60 saved: (100, 300, 300)
# Generating rules:  24%|██▍       | 62/256 [05:37<17:53,  5.53s/it]
# Rule 61 saved: (100, 300, 300)
# Generating rules:  25%|██▍       | 63/256 [05:42<17:17,  5.38s/it]
# Rule 62 saved: (100, 300, 300)
# Generating rules:  25%|██▌       | 64/256 [05:47<17:34,  5.49s/it]
# Rule 63 saved: (100, 300, 300)
# Generating rules:  25%|██▌       | 65/256 [05:53<17:12,  5.41s/it]
# Rule 64 saved: (100, 300, 300)
# Generating rules:  26%|██▌       | 66/256 [05:58<16:46,  5.30s/it]
# Rule 65 saved: (100, 300, 300)
# Generating rules:  26%|██▌       | 67/256 [06:04<17:17,  5.49s/it]
# Rule 66 saved: (100, 300, 300)
# Generating rules:  27%|██▋       | 68/256 [06:09<16:45,  5.35s/it]
# Rule 67 saved: (100, 300, 300)
# Generating rules:  27%|██▋       | 69/256 [06:15<17:11,  5.52s/it]
# Rule 68 saved: (100, 300, 300)
# Generating rules:  27%|██▋       | 70/256 [06:20<16:41,  5.38s/it]
# Rule 69 saved: (100, 300, 300)
# Generating rules:  28%|██▊       | 71/256 [06:25<16:28,  5.34s/it]
# Rule 70 saved: (100, 300, 300)
# Generating rules:  28%|██▊       | 72/256 [06:31<16:44,  5.46s/it]
# Rule 71 saved: (100, 300, 300)
# Generating rules:  29%|██▊       | 73/256 [06:36<16:17,  5.34s/it]
# Rule 72 saved: (100, 300, 300)
# Generating rules:  29%|██▉       | 74/256 [06:42<16:44,  5.52s/it]
# Rule 73 saved: (100, 300, 300)
# Generating rules:  29%|██▉       | 75/256 [06:47<16:13,  5.38s/it]
# Rule 74 saved: (100, 300, 300)
# Generating rules:  30%|██▉       | 76/256 [06:52<16:21,  5.45s/it]
# Rule 75 saved: (100, 300, 300)
# Generating rules:  30%|███       | 77/256 [06:58<16:15,  5.45s/it]
# Rule 76 saved: (100, 300, 300)
# Generating rules:  30%|███       | 78/256 [07:03<15:46,  5.32s/it]
# Rule 77 saved: (100, 300, 300)
# Generating rules:  31%|███       | 79/256 [07:09<16:18,  5.53s/it]
# Rule 78 saved: (100, 300, 300)
# Generating rules:  31%|███▏      | 80/256 [07:14<15:46,  5.38s/it]
# Rule 79 saved: (100, 300, 300)
# Generating rules:  32%|███▏      | 81/256 [07:20<16:11,  5.55s/it]
# Rule 80 saved: (100, 300, 300)
# Generating rules:  32%|███▏      | 82/256 [07:25<15:38,  5.39s/it]
# Rule 81 saved: (100, 300, 300)
# Generating rules:  32%|███▏      | 83/256 [07:30<15:17,  5.30s/it]
# Rule 82 saved: (100, 300, 300)
# Generating rules:  33%|███▎      | 84/256 [07:36<15:43,  5.48s/it]
# Rule 83 saved: (100, 300, 300)
# Generating rules:  33%|███▎      | 85/256 [07:41<15:14,  5.35s/it]
# Rule 84 saved: (100, 300, 300)
# Generating rules:  34%|███▎      | 86/256 [07:47<15:39,  5.53s/it]
# Rule 85 saved: (100, 300, 300)
# Generating rules:  34%|███▍      | 87/256 [07:52<15:12,  5.40s/it]
# Rule 86 saved: (100, 300, 300)
# Generating rules:  34%|███▍      | 88/256 [07:57<15:05,  5.39s/it]
# Rule 87 saved: (100, 300, 300)
# Generating rules:  35%|███▍      | 89/256 [08:03<15:08,  5.44s/it]
# Rule 88 saved: (100, 300, 300)
# Generating rules:  35%|███▌      | 90/256 [08:08<14:41,  5.31s/it]
# Rule 89 saved: (100, 300, 300)
# Generating rules:  36%|███▌      | 91/256 [08:14<15:06,  5.49s/it]
# Rule 90 saved: (100, 300, 300)
# Generating rules:  36%|███▌      | 92/256 [08:19<14:36,  5.35s/it]
# Rule 91 saved: (100, 300, 300)
# Generating rules:  36%|███▋      | 93/256 [08:24<14:47,  5.45s/it]
# Rule 92 saved: (100, 300, 300)
# Generating rules:  37%|███▋      | 94/256 [08:30<14:34,  5.40s/it]
# Rule 93 saved: (100, 300, 300)
# Generating rules:  37%|███▋      | 95/256 [08:35<14:12,  5.29s/it]
# Rule 94 saved: (100, 300, 300)
# Generating rules:  38%|███▊      | 96/256 [08:41<14:37,  5.48s/it]
# Rule 95 saved: (100, 300, 300)
# Generating rules:  38%|███▊      | 97/256 [08:46<14:09,  5.34s/it]
# Rule 96 saved: (100, 300, 300)
# Generating rules:  38%|███▊      | 98/256 [08:52<14:36,  5.55s/it]
# Rule 97 saved: (100, 300, 300)
# Generating rules:  39%|███▊      | 99/256 [08:57<14:05,  5.38s/it]
# Rule 98 saved: (100, 300, 300)
# Generating rules:  39%|███▉      | 100/256 [09:02<13:51,  5.33s/it]
# Rule 99 saved: (100, 300, 300)
# Generating rules:  39%|███▉      | 101/256 [09:08<14:07,  5.47s/it]
# Rule 100 saved: (100, 300, 300)
# Generating rules:  40%|███▉      | 102/256 [09:13<13:40,  5.33s/it]
# Rule 101 saved: (100, 300, 300)
# Generating rules:  40%|████      | 103/256 [09:19<14:06,  5.53s/it]
# Rule 102 saved: (100, 300, 300)
# Generating rules:  41%|████      | 104/256 [09:24<13:36,  5.37s/it]
# Rule 103 saved: (100, 300, 300)
# Generating rules:  41%|████      | 105/256 [09:29<13:33,  5.39s/it]
# Rule 104 saved: (100, 300, 300)
# Generating rules:  41%|████▏     | 106/256 [09:35<13:35,  5.43s/it]
# Rule 105 saved: (100, 300, 300)
# Generating rules:  42%|████▏     | 107/256 [09:40<13:11,  5.31s/it]
# Rule 106 saved: (100, 300, 300)
# Generating rules:  42%|████▏     | 108/256 [09:46<13:33,  5.50s/it]
# Rule 107 saved: (100, 300, 300)
# Generating rules:  43%|████▎     | 109/256 [09:51<13:05,  5.34s/it]
# Rule 108 saved: (100, 300, 300)
# Generating rules:  43%|████▎     | 110/256 [09:56<13:18,  5.47s/it]
# Rule 109 saved: (100, 300, 300)
# Generating rules:  43%|████▎     | 111/256 [10:02<13:03,  5.40s/it]
# Rule 110 saved: (100, 300, 300)
# Generating rules:  44%|████▍     | 112/256 [10:07<12:42,  5.29s/it]
# Rule 111 saved: (100, 300, 300)
# Generating rules:  44%|████▍     | 113/256 [10:13<13:05,  5.49s/it]
# Rule 112 saved: (100, 300, 300)
# Generating rules:  45%|████▍     | 114/256 [10:18<13:08,  5.55s/it]
# Rule 113 saved: (100, 300, 300)
# Generating rules:  45%|████▍     | 115/256 [10:27<14:55,  6.35s/it]
# Rule 114 saved: (100, 300, 300)
# Generating rules:  45%|████▌     | 116/256 [10:32<13:55,  5.96s/it]
# Rule 115 saved: (100, 300, 300)
# Generating rules:  46%|████▌     | 117/256 [10:37<13:32,  5.85s/it]
# Rule 116 saved: (100, 300, 300)
# Generating rules:  46%|████▌     | 118/256 [10:43<13:08,  5.72s/it]
# Rule 117 saved: (100, 300, 300)
# Generating rules:  46%|████▋     | 119/256 [10:48<12:39,  5.54s/it]
# Rule 118 saved: (100, 300, 300)
# Generating rules:  47%|████▋     | 120/256 [10:54<12:56,  5.71s/it]
# Rule 119 saved: (100, 300, 300)
# Generating rules:  47%|████▋     | 121/256 [10:59<12:23,  5.51s/it]
# Rule 120 saved: (100, 300, 300)
# Generating rules:  48%|████▊     | 122/256 [11:05<12:42,  5.69s/it]
# Rule 121 saved: (100, 300, 300)
# Generating rules:  48%|████▊     | 123/256 [11:10<12:10,  5.49s/it]
# Rule 122 saved: (100, 300, 300)
# Generating rules:  48%|████▊     | 124/256 [11:15<11:46,  5.36s/it]
# Rule 123 saved: (100, 300, 300)
# Generating rules:  49%|████▉     | 125/256 [11:21<12:09,  5.56s/it]
# Rule 124 saved: (100, 300, 300)
# Generating rules:  49%|████▉     | 126/256 [11:26<11:43,  5.41s/it]
# Rule 125 saved: (100, 300, 300)
# Generating rules:  50%|████▉     | 127/256 [11:32<12:04,  5.61s/it]
# Rule 126 saved: (100, 300, 300)
# Generating rules:  50%|█████     | 128/256 [11:37<11:35,  5.44s/it]
# Rule 127 saved: (100, 300, 300)
# Generating rules:  50%|█████     | 129/256 [11:43<11:29,  5.43s/it]
# Rule 128 saved: (100, 300, 300)
# Generating rules:  51%|█████     | 130/256 [11:48<11:33,  5.50s/it]
# Rule 129 saved: (100, 300, 300)
# Generating rules:  51%|█████     | 131/256 [11:53<11:13,  5.39s/it]
# Rule 130 saved: (100, 300, 300)
# Generating rules:  52%|█████▏    | 132/256 [12:00<11:32,  5.59s/it]
# Rule 131 saved: (100, 300, 300)
# Generating rules:  52%|█████▏    | 133/256 [12:05<11:07,  5.43s/it]
# Rule 132 saved: (100, 300, 300)
# Generating rules:  52%|█████▏    | 134/256 [12:10<11:12,  5.51s/it]
# Rule 133 saved: (100, 300, 300)
# Generating rules:  53%|█████▎    | 135/256 [12:16<10:59,  5.45s/it]
# Rule 134 saved: (100, 300, 300)
# Generating rules:  53%|█████▎    | 136/256 [12:21<10:38,  5.32s/it]
# Rule 135 saved: (100, 300, 300)
# Generating rules:  54%|█████▎    | 137/256 [12:27<10:56,  5.51s/it]
# Rule 136 saved: (100, 300, 300)
# Generating rules:  54%|█████▍    | 138/256 [12:32<10:33,  5.37s/it]
# Rule 137 saved: (100, 300, 300)
# Generating rules:  54%|█████▍    | 139/256 [12:38<10:53,  5.58s/it]
# Rule 138 saved: (100, 300, 300)
# Generating rules:  55%|█████▍    | 140/256 [12:43<10:28,  5.41s/it]
# Rule 139 saved: (100, 300, 300)
# Generating rules:  55%|█████▌    | 141/256 [12:48<10:12,  5.33s/it]
# Rule 140 saved: (100, 300, 300)
# Generating rules:  55%|█████▌    | 142/256 [12:54<10:30,  5.53s/it]
# Rule 141 saved: (100, 300, 300)
# Generating rules:  56%|█████▌    | 143/256 [12:59<10:10,  5.40s/it]
# Rule 142 saved: (100, 300, 300)
# Generating rules:  56%|█████▋    | 144/256 [13:05<10:27,  5.60s/it]
# Rule 143 saved: (100, 300, 300)
# Generating rules:  57%|█████▋    | 145/256 [13:10<10:01,  5.42s/it]
# Rule 144 saved: (100, 300, 300)
# Generating rules:  57%|█████▋    | 146/256 [13:15<09:58,  5.44s/it]
# Rule 145 saved: (100, 300, 300)
# Generating rules:  57%|█████▋    | 147/256 [13:21<09:56,  5.47s/it]
# Rule 146 saved: (100, 300, 300)
# Generating rules:  58%|█████▊    | 148/256 [13:26<09:36,  5.34s/it]
# Rule 147 saved: (100, 300, 300)
# Generating rules:  58%|█████▊    | 149/256 [13:32<09:53,  5.55s/it]
# Rule 148 saved: (100, 300, 300)
# Generating rules:  59%|█████▊    | 150/256 [13:37<09:32,  5.40s/it]
# Rule 149 saved: (100, 300, 300)
# Generating rules:  59%|█████▉    | 151/256 [13:43<09:44,  5.56s/it]
# Rule 150 saved: (100, 300, 300)
# Generating rules:  59%|█████▉    | 152/256 [13:48<09:26,  5.45s/it]
# Rule 151 saved: (100, 300, 300)
# Generating rules:  60%|█████▉    | 153/256 [13:53<09:08,  5.32s/it]
# Rule 152 saved: (100, 300, 300)
# Generating rules:  60%|██████    | 154/256 [13:59<09:24,  5.54s/it]
# Rule 153 saved: (100, 300, 300)
# Generating rules:  61%|██████    | 155/256 [14:04<09:06,  5.41s/it]
# Rule 154 saved: (100, 300, 300)
# Generating rules:  61%|██████    | 156/256 [14:10<09:16,  5.57s/it]
# Rule 155 saved: (100, 300, 300)
# Generating rules:  61%|██████▏   | 157/256 [14:15<08:54,  5.40s/it]
# Rule 156 saved: (100, 300, 300)
# Generating rules:  62%|██████▏   | 158/256 [14:21<08:43,  5.34s/it]
# Rule 157 saved: (100, 300, 300)
# Generating rules:  62%|██████▏   | 159/256 [14:26<08:52,  5.49s/it]
# Rule 158 saved: (100, 300, 300)
# Generating rules:  62%|██████▎   | 160/256 [14:31<08:34,  5.35s/it]
# Rule 159 saved: (100, 300, 300)
# Generating rules:  63%|██████▎   | 161/256 [14:38<08:48,  5.57s/it]
# Rule 160 saved: (100, 300, 300)
# Generating rules:  63%|██████▎   | 162/256 [14:43<08:28,  5.41s/it]
# Rule 161 saved: (100, 300, 300)
# Generating rules:  64%|██████▎   | 163/256 [14:48<08:31,  5.50s/it]
# Rule 162 saved: (100, 300, 300)
# Generating rules:  64%|██████▍   | 164/256 [14:54<08:24,  5.48s/it]
# Rule 163 saved: (100, 300, 300)
# Generating rules:  64%|██████▍   | 165/256 [14:59<08:06,  5.35s/it]
# Rule 164 saved: (100, 300, 300)
# Generating rules:  65%|██████▍   | 166/256 [15:05<08:18,  5.54s/it]
# Rule 165 saved: (100, 300, 300)
# Generating rules:  65%|██████▌   | 167/256 [15:10<08:00,  5.40s/it]
# Rule 166 saved: (100, 300, 300)
# Generating rules:  66%|██████▌   | 168/256 [15:16<08:17,  5.65s/it]
# Rule 167 saved: (100, 300, 300)
# Generating rules:  66%|██████▌   | 169/256 [15:21<08:01,  5.53s/it]
# Rule 168 saved: (100, 300, 300)
# Generating rules:  66%|██████▋   | 170/256 [15:26<07:46,  5.42s/it]
# Rule 169 saved: (100, 300, 300)
# Generating rules:  67%|██████▋   | 171/256 [15:32<07:53,  5.57s/it]
# Rule 170 saved: (100, 300, 300)
# Generating rules:  67%|██████▋   | 172/256 [15:37<07:35,  5.43s/it]
# Rule 171 saved: (100, 300, 300)
# Generating rules:  68%|██████▊   | 173/256 [15:43<07:44,  5.59s/it]
# Rule 172 saved: (100, 300, 300)
# Generating rules:  68%|██████▊   | 174/256 [15:48<07:24,  5.42s/it]
# Rule 173 saved: (100, 300, 300)
# Generating rules:  68%|██████▊   | 175/256 [15:54<07:23,  5.47s/it]
# Rule 174 saved: (100, 300, 300)
# Generating rules:  69%|██████▉   | 176/256 [16:00<07:18,  5.49s/it]
# Rule 175 saved: (100, 300, 300)
# Generating rules:  69%|██████▉   | 177/256 [16:05<07:01,  5.34s/it]
# Rule 176 saved: (100, 300, 300)
# Generating rules:  70%|██████▉   | 178/256 [16:11<07:10,  5.52s/it]
# Rule 177 saved: (100, 300, 300)
# Generating rules:  70%|██████▉   | 179/256 [16:16<06:53,  5.37s/it]
# Rule 178 saved: (100, 300, 300)
# Generating rules:  70%|███████   | 180/256 [16:21<06:57,  5.49s/it]
# Rule 179 saved: (100, 300, 300)
# Generating rules:  71%|███████   | 181/256 [16:26<06:44,  5.40s/it]
# Rule 180 saved: (100, 300, 300)
# Generating rules:  71%|███████   | 182/256 [16:32<06:30,  5.28s/it]
# Rule 181 saved: (100, 300, 300)
# Generating rules:  71%|███████▏  | 183/256 [16:38<06:43,  5.52s/it]
# Rule 182 saved: (100, 300, 300)
# Generating rules:  72%|███████▏  | 184/256 [16:43<06:27,  5.38s/it]
# Rule 183 saved: (100, 300, 300)
# Generating rules:  72%|███████▏  | 185/256 [16:49<06:34,  5.55s/it]
# Rule 184 saved: (100, 300, 300)
# Generating rules:  73%|███████▎  | 186/256 [16:54<06:17,  5.40s/it]
# Rule 185 saved: (100, 300, 300)
# Generating rules:  73%|███████▎  | 187/256 [16:59<06:10,  5.37s/it]
# Rule 186 saved: (100, 300, 300)
# Generating rules:  73%|███████▎  | 188/256 [17:05<06:14,  5.50s/it]
# Rule 187 saved: (100, 300, 300)
# Generating rules:  74%|███████▍  | 189/256 [17:10<05:59,  5.37s/it]
# Rule 188 saved: (100, 300, 300)
# Generating rules:  74%|███████▍  | 190/256 [17:16<06:06,  5.55s/it]
# Rule 189 saved: (100, 300, 300)
# Generating rules:  75%|███████▍  | 191/256 [17:21<05:51,  5.41s/it]
# Rule 190 saved: (100, 300, 300)
# Generating rules:  75%|███████▌  | 192/256 [17:27<05:54,  5.54s/it]
# Rule 191 saved: (100, 300, 300)
# Generating rules:  75%|███████▌  | 193/256 [17:32<05:46,  5.50s/it]
# Rule 192 saved: (100, 300, 300)
# Generating rules:  76%|███████▌  | 194/256 [17:37<05:33,  5.38s/it]
# Rule 193 saved: (100, 300, 300)
# Generating rules:  76%|███████▌  | 195/256 [17:43<05:42,  5.61s/it]
# Rule 194 saved: (100, 300, 300)
# Generating rules:  77%|███████▋  | 196/256 [17:48<05:26,  5.45s/it]
# Rule 195 saved: (100, 300, 300)
# Generating rules:  77%|███████▋  | 197/256 [17:54<05:29,  5.59s/it]
# Rule 196 saved: (100, 300, 300)
# Generating rules:  77%|███████▋  | 198/256 [17:59<05:14,  5.42s/it]
# Rule 197 saved: (100, 300, 300)
# Generating rules:  78%|███████▊  | 199/256 [18:05<05:06,  5.38s/it]
# Rule 198 saved: (100, 300, 300)
# Generating rules:  78%|███████▊  | 200/256 [18:10<05:06,  5.48s/it]
# Rule 199 saved: (100, 300, 300)
# Generating rules:  79%|███████▊  | 201/256 [18:15<04:54,  5.35s/it]
# Rule 200 saved: (100, 300, 300)
# Generating rules:  79%|███████▉  | 202/256 [18:21<04:58,  5.53s/it]
# Rule 201 saved: (100, 300, 300)
# Generating rules:  79%|███████▉  | 203/256 [18:26<04:45,  5.39s/it]
# Rule 202 saved: (100, 300, 300)
# Generating rules:  80%|███████▉  | 204/256 [18:32<04:44,  5.48s/it]
# Rule 203 saved: (100, 300, 300)
# Generating rules:  80%|████████  | 205/256 [18:37<04:38,  5.46s/it]
# Rule 204 saved: (100, 300, 300)
# Generating rules:  80%|████████  | 206/256 [18:43<04:26,  5.34s/it]
# Rule 205 saved: (100, 300, 300)
# Generating rules:  81%|████████  | 207/256 [18:49<04:31,  5.54s/it]
# Rule 206 saved: (100, 300, 300)
# Generating rules:  81%|████████▏ | 208/256 [18:54<04:18,  5.40s/it]
# Rule 207 saved: (100, 300, 300)
# Generating rules:  82%|████████▏ | 209/256 [19:00<04:22,  5.58s/it]
# Rule 208 saved: (100, 300, 300)
# Generating rules:  82%|████████▏ | 210/256 [19:05<04:09,  5.42s/it]
# Rule 209 saved: (100, 300, 300)
# Generating rules:  82%|████████▏ | 211/256 [19:10<04:01,  5.36s/it]
# Rule 210 saved: (100, 300, 300)
# Generating rules:  83%|████████▎ | 212/256 [19:16<04:02,  5.51s/it]
# Rule 211 saved: (100, 300, 300)
# Generating rules:  83%|████████▎ | 213/256 [19:21<03:51,  5.37s/it]
# Rule 212 saved: (100, 300, 300)
# Generating rules:  84%|████████▎ | 214/256 [19:27<03:53,  5.55s/it]
# Rule 213 saved: (100, 300, 300)
# Generating rules:  84%|████████▍ | 215/256 [19:32<03:42,  5.42s/it]
# Rule 214 saved: (100, 300, 300)
# Generating rules:  84%|████████▍ | 216/256 [19:37<03:38,  5.46s/it]
# Rule 215 saved: (100, 300, 300)
# Generating rules:  85%|████████▍ | 217/256 [19:43<03:32,  5.45s/it]
# Rule 216 saved: (100, 300, 300)
# Generating rules:  85%|████████▌ | 218/256 [19:48<03:22,  5.34s/it]
# Rule 217 saved: (100, 300, 300)
# Generating rules:  86%|████████▌ | 219/256 [19:54<03:24,  5.54s/it]
# Rule 218 saved: (100, 300, 300)
# Generating rules:  86%|████████▌ | 220/256 [19:59<03:14,  5.39s/it]
# Rule 219 saved: (100, 300, 300)
# Generating rules:  86%|████████▋ | 221/256 [20:05<03:15,  5.59s/it]
# Rule 220 saved: (100, 300, 300)
# Generating rules:  87%|████████▋ | 222/256 [20:10<03:05,  5.45s/it]
# Rule 221 saved: (100, 300, 300)
# Generating rules:  87%|████████▋ | 223/256 [20:15<02:56,  5.36s/it]
# Rule 222 saved: (100, 300, 300)
# Generating rules:  88%|████████▊ | 224/256 [20:21<02:57,  5.53s/it]
# Rule 223 saved: (100, 300, 300)
# Generating rules:  88%|████████▊ | 225/256 [20:27<02:49,  5.48s/it]
# Rule 224 saved: (100, 300, 300)
# Generating rules:  88%|████████▊ | 226/256 [20:35<03:11,  6.39s/it]
# Rule 225 saved: (100, 300, 300)
# Generating rules:  89%|████████▊ | 227/256 [20:40<02:54,  6.00s/it]
# Rule 226 saved: (100, 300, 300)
# Generating rules:  89%|████████▉ | 228/256 [20:46<02:47,  5.99s/it]
# Rule 227 saved: (100, 300, 300)
# Generating rules:  89%|████████▉ | 229/256 [20:51<02:35,  5.76s/it]
# Rule 228 saved: (100, 300, 300)
# Generating rules:  90%|████████▉ | 230/256 [20:57<02:25,  5.61s/it]
# Rule 229 saved: (100, 300, 300)
# Generating rules:  90%|█████████ | 231/256 [21:03<02:24,  5.76s/it]
# Rule 230 saved: (100, 300, 300)
# Generating rules:  91%|█████████ | 232/256 [21:08<02:13,  5.56s/it]
# Rule 231 saved: (100, 300, 300)
# Generating rules:  91%|█████████ | 233/256 [21:14<02:11,  5.71s/it]
# Rule 232 saved: (100, 300, 300)
# Generating rules:  91%|█████████▏| 234/256 [21:19<02:01,  5.53s/it]
# Rule 233 saved: (100, 300, 300)
# Generating rules:  92%|█████████▏| 235/256 [21:25<01:56,  5.53s/it]
# Rule 234 saved: (100, 300, 300)
# Generating rules:  92%|█████████▏| 236/256 [21:30<01:51,  5.55s/it]
# Rule 235 saved: (100, 300, 300)
# Generating rules:  93%|█████████▎| 237/256 [21:35<01:43,  5.43s/it]
# Rule 236 saved: (100, 300, 300)
# Generating rules:  93%|█████████▎| 238/256 [21:41<01:40,  5.61s/it]
# Rule 237 saved: (100, 300, 300)
# Generating rules:  93%|█████████▎| 239/256 [21:46<01:32,  5.44s/it]
# Rule 238 saved: (100, 300, 300)
# Generating rules:  94%|█████████▍| 240/256 [21:52<01:29,  5.58s/it]
# Rule 239 saved: (100, 300, 300)
# Generating rules:  94%|█████████▍| 241/256 [21:58<01:22,  5.48s/it]
# Rule 240 saved: (100, 300, 300)
# Generating rules:  95%|█████████▍| 242/256 [22:03<01:14,  5.34s/it]
# Rule 241 saved: (100, 300, 300)
# Generating rules:  95%|█████████▍| 243/256 [22:09<01:12,  5.54s/it]
# Rule 242 saved: (100, 300, 300)
# Generating rules:  95%|█████████▌| 244/256 [22:14<01:04,  5.38s/it]
# Rule 243 saved: (100, 300, 300)
# Generating rules:  96%|█████████▌| 245/256 [22:20<01:01,  5.59s/it]
# Rule 244 saved: (100, 300, 300)
# Generating rules:  96%|█████████▌| 246/256 [22:25<00:54,  5.42s/it]
# Rule 245 saved: (100, 300, 300)
# Generating rules:  96%|█████████▋| 247/256 [22:30<00:48,  5.41s/it]
# Rule 246 saved: (100, 300, 300)
# Generating rules:  97%|█████████▋| 248/256 [22:36<00:44,  5.51s/it]
# Rule 247 saved: (100, 300, 300)
# Generating rules:  97%|█████████▋| 249/256 [22:41<00:37,  5.39s/it]
# Rule 248 saved: (100, 300, 300)
# Generating rules:  98%|█████████▊| 250/256 [22:47<00:33,  5.58s/it]
# Rule 249 saved: (100, 300, 300)
# Generating rules:  98%|█████████▊| 251/256 [22:53<00:27,  5.59s/it]
# Rule 250 saved: (100, 300, 300)
# Generating rules:  98%|█████████▊| 252/256 [22:59<00:22,  5.72s/it]
# Rule 251 saved: (100, 300, 300)
# Generating rules:  99%|█████████▉| 253/256 [23:04<00:16,  5.55s/it]
# Rule 252 saved: (100, 300, 300)
# Generating rules:  99%|█████████▉| 254/256 [23:09<00:10,  5.45s/it]
# Rule 253 saved: (100, 300, 300)
# Generating rules: 100%|█████████▉| 255/256 [23:15<00:05,  5.60s/it]
# Rule 254 saved: (100, 300, 300)
# Generating rules: 100%|██████████| 256/256 [23:20<00:00,  5.47s/it]
# Rule 255 saved: (100, 300, 300)
#
# ======================================
# CODE 1 COMPLETE
# ======================================
# Saved folder: CA_Snapshots_256
# Each rule: (100, 300, 300)
# Total rules: 256

# %%
# ============================================================
# CODE 2
# CA NATURE CLASSIFICATION
#
# INPUT:
#       Saved snapshots generated by CODE 1
#
# ANALYSED RULES:
#       Rule 195 to Rule 255
#
# TOTAL:
#       61 rules
#
# INPUT FOLDER:
#       CA_Snapshots_256
#
# EACH INPUT FILE:
#       shape = (100, 300, 300)
#
# CLASSIFICATION:
#       1. Fixed Point
#       2. Periodic
#       3. Unknown
#
# IMPORTANT:
#       FULL 300 x 300 MATRIX IS USED
#       NO MIDDLE ROW
#       NO CA REGENERATION
# ============================================================


import numpy as np
import pandas as pd
import os
from tqdm import tqdm


# ============================================================
# 1. PARAMETERS
# ============================================================

INPUT_FOLDER = "CA_Snapshots_256"

FIRST_RULE = 195
LAST_RULE = 255

TIME_STEPS = 100

GRID_ROWS = 300
GRID_COLS = 300


# ============================================================
# 2. CHECK TWO COMPLETE SNAPSHOTS
# ============================================================

def same_snapshot(
    snapshot1,
    snapshot2
):

    return np.array_equal(
        snapshot1,
        snapshot2
    )


# ============================================================
# 3. DETECT FIXED POINT / PERIODIC / UNKNOWN
#
# First-recurrence method:
#
# CA evolution is deterministic, so if:
#
#       S(t) = S(t+k)
#
# then the trajectory is periodic with period k
# from time t onward.
#
# cycle == 1  -> Fixed Point
# cycle >= 2  -> Periodic
# never found -> Unknown
#
# Complete 300 x 300 matrix is used.
# ============================================================

def detect_nature(
    snapshots
):

    n = len(
        snapshots
    )

    state_history = {}


    for step in range(
        n
    ):

        # Convert complete 300 x 300 state to bytes
        current_state = snapshots[
            step
        ].tobytes()


        # Check whether this complete state
        # appeared before
        if current_state in state_history:

            transient = state_history[
                current_state
            ]

            cycle = (
                step
                -
                transient
            )


            # Fixed Point
            if cycle == 1:

                return (
                    "Fixed Point",
                    transient,
                    cycle
                )


            # Periodic
            else:

                return (
                    "Periodic",
                    transient,
                    cycle
                )


        # New state
        else:

            state_history[
                current_state
            ] = step


    # No exact recurrence found
    # within the 100 saved snapshots
    return (
        "Unknown",
        -1,
        0
    )


# ============================================================
# 4. PROCESS RULES
# ============================================================

results = []


print("\n==========================================")
print("CA NATURE ANALYSIS")
print("==========================================")

print(
    f"Rules analysed: "
    f"{FIRST_RULE} to {LAST_RULE}"
)

print(
    f"Total rules: "
    f"{LAST_RULE - FIRST_RULE + 1}"
)

print(
    f"Grid used: "
    f"{GRID_ROWS} x {GRID_COLS}"
)

print(
    f"Time steps: "
    f"{TIME_STEPS}"
)


# ============================================================
# 5. LOOP THROUGH RULES
# ============================================================

for rule_number in tqdm(
    range(
        FIRST_RULE,
        LAST_RULE + 1
    ),
    desc="Analysing rules"
):


    # --------------------------------------------------------
    # File name
    # --------------------------------------------------------

    file_path = os.path.join(
        INPUT_FOLDER,
        f"Rule_{rule_number:03d}.npy"
    )


    # --------------------------------------------------------
    # Check file
    # --------------------------------------------------------

    if not os.path.exists(
        file_path
    ):

        print(
            f"\nWARNING: "
            f"Rule {rule_number} file not found."
        )

        continue


    # ========================================================
    # LOAD SAVED SNAPSHOTS
    # ========================================================

    snapshots = np.load(
        file_path
    )


    # ========================================================
    # CHECK SHAPE
    # ========================================================

    if snapshots.shape != (
        TIME_STEPS,
        GRID_ROWS,
        GRID_COLS
    ):

        print(
            f"\nWARNING: Rule {rule_number} "
            f"has shape {snapshots.shape}"
        )

        del snapshots

        continue


    # ========================================================
    # NATURE DETECTION
    #
    # Fixed Point / Periodic / Unknown
    # ========================================================

    (
        nature,
        transient_length,
        cycle_length
    ) = detect_nature(
        snapshots
    )


    # ========================================================
    # EXTRA INFORMATION
    # ========================================================


    # --------------------------------------------------------
    # Final density
    # --------------------------------------------------------

    final_density = float(
        snapshots[
            -1
        ].mean()
    )


    # --------------------------------------------------------
    # Mean density
    # --------------------------------------------------------

    mean_density = float(
        snapshots.mean()
    )


    # --------------------------------------------------------
    # State change rates
    #
    # Complete 300 x 300 matrices are compared.
    # --------------------------------------------------------

    change_rates = []


    for t in range(
        1,
        TIME_STEPS
    ):

        change_rate = np.mean(
            snapshots[
                t
            ]
            !=
            snapshots[
                t - 1
            ]
        )

        change_rates.append(
            change_rate
        )


    change_rates = np.array(
        change_rates
    )


    # --------------------------------------------------------
    # Mean state change rate
    # --------------------------------------------------------

    mean_state_change_rate = float(
        change_rates.mean()
    )


    # --------------------------------------------------------
    # Final state change rate
    # --------------------------------------------------------

    final_state_change_rate = float(
        change_rates[
            -1
        ]
    )


    # ========================================================
    # STORE RESULT
    # ========================================================

    results.append({

        "Rule":
            rule_number,

        "Nature":
            nature,

        "Transient_Length":
            transient_length,

        "Cycle_Length":
            cycle_length,

        "Final_Density":
            final_density,

        "Mean_Density":
            mean_density,

        "Mean_State_Change_Rate":
            mean_state_change_rate,

        "Final_State_Change_Rate":
            final_state_change_rate

    })


    # ========================================================
    # FREE MEMORY
    # ========================================================

    del snapshots


# ============================================================
# 6. CREATE DATAFRAME
# ============================================================

results_df = pd.DataFrame(
    results
)


# ============================================================
# 7. SORT BY RULE NUMBER
# ============================================================

results_df = results_df.sort_values(
    "Rule"
).reset_index(
    drop=True
)


# ============================================================
# 8. SAVE CSV
# ============================================================

CSV_FILE = (
    "CA_Nature_Analysis_Rules_195_to_255.csv"
)


results_df.to_csv(
    CSV_FILE,
    index=False
)


# ============================================================
# 9. SAVE EXCEL
# ============================================================

EXCEL_FILE = (
    "CA_Nature_Analysis_Rules_195_to_255.xlsx"
)


results_df.to_excel(
    EXCEL_FILE,
    index=False
)


# ============================================================
# 10. DISPLAY RESULTS
# ============================================================

print("\n==========================================")
print("ANALYSIS COMPLETE")
print("==========================================")

print(
    results_df[
        [
            "Rule",
            "Nature",
            "Transient_Length",
            "Cycle_Length"
        ]
    ].to_string(
        index=False
    )
)


# ============================================================
# 11. NATURE COUNTS
# ============================================================

print("\n==========================================")
print("NATURE COUNTS")
print("==========================================")

nature_counts = (
    results_df[
        "Nature"
    ].value_counts()
)


print(
    nature_counts
)


# ============================================================
# 12. FINAL SUMMARY
# ============================================================

print("\n==========================================")
print("FINAL SUMMARY")
print("==========================================")

print(
    "Rules analysed:",
    len(
        results_df
    )
)

print(
    "Fixed Point:",
    int(
        (
            results_df[
                "Nature"
            ]
            == "Fixed Point"
        ).sum()
    )
)

print(
    "Periodic:",
    int(
        (
            results_df[
                "Nature"
            ]
            == "Periodic"
        ).sum()
    )
)

print(
    "Unknown:",
    int(
        (
            results_df[
                "Nature"
            ]
            == "Unknown"
        ).sum()
    )
)


print("\nFiles saved:")

print(
    CSV_FILE
)

print(
    EXCEL_FILE
)
# Out:
# ==========================================
# CA NATURE ANALYSIS
# ==========================================
# Rules analysed: 195 to 255
# Total rules: 61
# Grid used: 300 x 300
# Time steps: 100
# Analysing rules: 100%|██████████| 61/61 [00:01<00:00, 40.56it/s]
# ==========================================
# ANALYSIS COMPLETE
# ==========================================
#  Rule   Nature  Transient_Length  Cycle_Length
#   195  Unknown                -1             0
#   196 Periodic                 7             2
#   197 Periodic                31             6
#   198 Periodic                46            12
#   199  Unknown                -1             0
#   200 Periodic                 8             2
#   201  Unknown                -1             0
#   202  Unknown                -1             0
#   203  Unknown                -1             0
#   204 Periodic                11             2
#   205 Periodic                34            12
#   206 Periodic                87            12
#   207  Unknown                -1             0
#   208 Periodic                 6             2
#   209 Periodic                25             6
#   210 Periodic                47            24
#   211  Unknown                -1             0
#   212 Periodic                 7             2
#   213 Periodic                34             6
#   214  Unknown                -1             0
#   215  Unknown                -1             0
#   216 Periodic                32             8
#   217  Unknown                -1             0
#   218  Unknown                -1             0
#   219  Unknown                -1             0
#   220 Periodic                47            24
#   221 Periodic                43            24
#   222  Unknown                -1             0
#   223  Unknown                -1             0
#   224 Periodic                 7             2
#   225  Unknown                -1             0
#   226 Periodic                48            24
#   227  Unknown                -1             0
#   228 Periodic                39            12
#   229  Unknown                -1             0
#   230  Unknown                -1             0
#   231  Unknown                -1             0
#   232 Periodic                15             2
#   233  Unknown                -1             0
#   234  Unknown                -1             0
#   235  Unknown                -1             0
#   236 Periodic                45            24
#   237  Unknown                -1             0
#   238  Unknown                -1             0
#   239  Unknown                -1             0
#   240 Periodic                11             4
#   241 Periodic                51            12
#   242  Unknown                -1             0
#   243  Unknown                -1             0
#   244 Periodic                36            12
#   245 Periodic                46            24
#   246  Unknown                -1             0
#   247  Unknown                -1             0
#   248 Periodic                53            24
#   249  Unknown                -1             0
#   250  Unknown                -1             0
#   251  Unknown                -1             0
#   252  Unknown                -1             0
#   253  Unknown                -1             0
#   254  Unknown                -1             0
#   255  Unknown                -1             0
#
# ==========================================
# NATURE COUNTS
# ==========================================
# Nature
# Unknown     36
# Periodic    25
# Name: count, dtype: int64
#
# ==========================================
# FINAL SUMMARY
# ==========================================
# Rules analysed: 61
# Fixed Point: 0
# Periodic: 25
# Unknown: 36
#
# Files saved:
# CA_Nature_Analysis_Rules_195_to_255.csv
# CA_Nature_Analysis_Rules_195_to_255.xlsx

# %%
# ============================================================
# CA NATURE CLASSIFICATION
#
# CLASSIFICATION:
#       1. Fixed Point
#       2. Periodic
#       3. Unknown
#
# INPUT:
#       Saved .npy CA snapshots
#
# CURRENTLY GENERATED:
#       Rule 000 to Rule 195
#       = 196 rules
#
# EACH FILE:
#       (100, 300, 300)
#
# IMPORTANT:
#       FULL 300 x 300 MATRIX IS USED
#       NO MIDDLE ROW
#       NO CA REGENERATION
# ============================================================


import numpy as np
import pandas as pd
import os
from tqdm import tqdm


# ============================================================
# 1. PARAMETERS
# ============================================================

INPUT_FOLDER = "CA_Snapshots_256"

FIRST_RULE = 0
LAST_RULE = 195

TIME_STEPS = 100

GRID_ROWS = 300
GRID_COLS = 300


# ============================================================
# 2. CHECK TWO COMPLETE SNAPSHOTS
# ============================================================

def same_snapshot(
    snapshot1,
    snapshot2
):

    return np.array_equal(
        snapshot1,
        snapshot2
    )


# ============================================================
# 3. DETECT FIXED POINT / PERIODIC / UNKNOWN
#
# First-recurrence method:
#
# CA evolution is deterministic, so if S(t) = S(t+k) for any
# t, k, the trajectory is provably periodic with period k
# from t onward. No repeat-counting is needed.
#
# cycle == 1  -> Fixed Point
# cycle >= 2  -> Periodic
# never found -> Unknown
# ============================================================

def detect_nature(
    snapshots
):

    n = len(
        snapshots
    )

    state_history = {}

    for step in range(n):

        current_state = snapshots[step].tobytes()

        if current_state in state_history:

            transient = state_history[current_state]
            cycle = step - transient

            if cycle == 1:

                return "Fixed Point", transient, cycle

            else:

                return "Periodic", transient, cycle

        else:

            state_history[current_state] = step

    return "Unknown", -1, 0


# ============================================================
# 5. PROCESS RULES
# ============================================================

results = []


print("\n==========================================")
print("CA NATURE ANALYSIS")
print("==========================================")

print(
    f"Rules analysed: "
    f"{FIRST_RULE} to {LAST_RULE}"
)

print(
    f"Total rules: "
    f"{LAST_RULE - FIRST_RULE + 1}"
)

print(
    f"Grid used: "
    f"{GRID_ROWS} x {GRID_COLS}"
)

print(
    f"Time steps: "
    f"{TIME_STEPS}"
)


# ============================================================
# LOOP THROUGH RULES
# ============================================================

for rule_number in tqdm(
    range(
        FIRST_RULE,
        LAST_RULE + 1
    ),
    desc="Analysing rules"
):

    # --------------------------------------------------------
    # File name
    # --------------------------------------------------------

    file_path = os.path.join(
        INPUT_FOLDER,
        f"Rule_{rule_number:03d}.npy"
    )


    # --------------------------------------------------------
    # Check file
    # --------------------------------------------------------

    if not os.path.exists(
        file_path
    ):

        print(
            f"\nWARNING: "
            f"Rule {rule_number} file not found."
        )

        continue


    # ========================================================
    # LOAD SAVED SNAPSHOTS
    # ========================================================

    snapshots = np.load(
        file_path
    )


    # ========================================================
    # CHECK SHAPE
    # ========================================================

    if snapshots.shape != (
        TIME_STEPS,
        GRID_ROWS,
        GRID_COLS
    ):

        print(
            f"\nWARNING: Rule {rule_number} "
            f"has shape {snapshots.shape}"
        )

        del snapshots

        continue


    # ========================================================
    # NATURE DETECTION (Fixed Point / Periodic / Unknown)
    # ========================================================

    (
        nature,
        transient_length,
        cycle_length
    ) = detect_nature(
        snapshots
    )


    # ========================================================
    # EXTRA INFORMATION
    # ========================================================

    # --------------------------------------------------------
    # Final density
    # --------------------------------------------------------

    final_density = float(
        snapshots[-1].mean()
    )


    # --------------------------------------------------------
    # Mean density
    # --------------------------------------------------------

    mean_density = float(
        snapshots.mean()
    )


    # --------------------------------------------------------
    # State change rates
    #
    # Complete 300 x 300 matrices are compared.
    # --------------------------------------------------------

    change_rates = []

    for t in range(
        1,
        TIME_STEPS
    ):

        change_rate = np.mean(
            snapshots[t]
            !=
            snapshots[t - 1]
        )

        change_rates.append(
            change_rate
        )


    change_rates = np.array(
        change_rates
    )


    mean_state_change_rate = float(
        change_rates.mean()
    )


    final_state_change_rate = float(
        change_rates[-1]
    )


    # ========================================================
    # STORE RESULT
    # ========================================================

    results.append({

        "Rule":
            rule_number,

        "Nature":
            nature,

        "Transient_Length":
            transient_length,

        "Cycle_Length":
            cycle_length,

        "Final_Density":
            final_density,

        "Mean_Density":
            mean_density,

        "Mean_State_Change_Rate":
            mean_state_change_rate,

        "Final_State_Change_Rate":
            final_state_change_rate

    })


    # ========================================================
    # FREE MEMORY
    # ========================================================

    del snapshots


# ============================================================
# 6. CREATE DATAFRAME
# ============================================================

results_df = pd.DataFrame(
    results
)


# ============================================================
# 7. SORT BY RULE NUMBER
# ============================================================

results_df = results_df.sort_values(
    "Rule"
).reset_index(
    drop=True
)


# ============================================================
# 8. SAVE CSV
# ============================================================

CSV_FILE = (
    "CA_Nature_Analysis_Rules_000_to_195.csv"
)

results_df.to_csv(
    CSV_FILE,
    index=False
)


# ============================================================
# 9. SAVE EXCEL
# ============================================================

EXCEL_FILE = (
    "CA_Nature_Analysis_Rules_000_to_195.xlsx"
)

results_df.to_excel(
    EXCEL_FILE,
    index=False
)


# ============================================================
# 10. DISPLAY RESULTS
# ============================================================

print("\n==========================================")
print("ANALYSIS COMPLETE")
print("==========================================")

print(
    results_df[
        [
            "Rule",
            "Nature",
            "Transient_Length",
            "Cycle_Length"
        ]
    ].to_string(
        index=False
    )
)


# ============================================================
# 11. NATURE COUNTS
# ============================================================

print("\n==========================================")
print("NATURE COUNTS")
print("==========================================")

nature_counts = (
    results_df[
        "Nature"
    ].value_counts()
)


print(
    nature_counts
)


# ============================================================
# 12. FINAL SUMMARY
# ============================================================

print("\n==========================================")
print("FINAL SUMMARY")
print("==========================================")

print(
    "Rules analysed:",
    len(results_df)
)

print(
    "Fixed Point:",
    int(
        (
            results_df["Nature"]
            == "Fixed Point"
        ).sum()
    )
)

print(
    "Periodic:",
    int(
        (
            results_df["Nature"]
            == "Periodic"
        ).sum()
    )
)

print(
    "Unknown:",
    int(
        (
            results_df["Nature"]
            == "Unknown"
        ).sum()
    )
)

print("\nFiles saved:")

print(
    CSV_FILE
)

print(
    EXCEL_FILE
)

# %%
# ============================================================
# 100-PAGE SPACE-TIME VISUALIZATION FOR ONE RULE
#
# CHANGE ONLY:
#       RULE_NO = 0
#
# OUTPUT:
#       Rule_000_100_Steps.pdf
#
# Page 1  -> t = 0
# Page 2  -> t = 1
# ...
# Page 100 -> t = 99
#
# EACH PAGE = FULL 300 x 300 GRID
#
# READS EXISTING .npy FILE
# DOES NOT REGENERATE CA
# DOES NOT USE MIDDLE ROW
# ============================================================

import numpy as np
import os
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages


# ============================================================
# CHANGE THIS NUMBER ONLY
# ============================================================

RULE_NO = 196


# ============================================================
# SETTINGS
# ============================================================

INPUT_FOLDER = "CA_Snapshots_256"

TIME_STEPS_TO_SAVE = 100


# ============================================================
# FILE PATHS
# ============================================================

input_file = os.path.join(
    INPUT_FOLDER,
    f"Rule_{RULE_NO:03d}.npy"
)

output_file = (
    f"Rule_{RULE_NO:03d}_100_Steps.pdf"
)


# ============================================================
# CHECK INPUT FILE
# ============================================================

if not os.path.exists(input_file):

    raise FileNotFoundError(
        f"File not found:\n{input_file}"
    )


# ============================================================
# LOAD ONE RULE
# ============================================================

snapshots = np.load(
    input_file
)

print("Loaded:", input_file)
print("Shape:", snapshots.shape)


# ============================================================
# CHECK SHAPE
# ============================================================

if snapshots.shape != (
    100,
    300,
    300
):

    raise ValueError(
        f"Expected shape (100, 300, 300), "
        f"but got {snapshots.shape}"
    )


# ============================================================
# CREATE 100-PAGE PDF
# ============================================================

with PdfPages(output_file) as pdf:

    for t in range(
        TIME_STEPS_TO_SAVE
    ):

        # ----------------------------------------------------
        # COMPLETE 300 x 300 CONFIGURATION
        # ----------------------------------------------------

        grid = snapshots[t]


        # ----------------------------------------------------
        # CREATE PAGE
        # ----------------------------------------------------

        fig, ax = plt.subplots(
            figsize=(8, 8)
        )


        # ----------------------------------------------------
        # DISPLAY FULL GRID
        # ----------------------------------------------------

        ax.imshow(
            grid,
            cmap="binary",
            interpolation="nearest",
            aspect="equal"
        )


        # ----------------------------------------------------
        # TITLE
        # ----------------------------------------------------

        ax.set_title(
            f"Rule {RULE_NO} | Time Step t = {t}\n"
            f"Full 300 × 300 Configuration",
            fontsize=14
        )


        # ----------------------------------------------------
        # AXES
        # ----------------------------------------------------

        ax.set_xlabel(
            "Column (0–299)"
        )

        ax.set_ylabel(
            "Row (0–299)"
        )


        # ----------------------------------------------------
        # SAVE THIS PAGE
        # ----------------------------------------------------

        plt.tight_layout()

        pdf.savefig(
            fig,
            dpi=100
        )

        plt.close(fig)


# ============================================================
# RELEASE MEMORY
# ============================================================

del snapshots


# ============================================================
# COMPLETE
# ============================================================

print("\n==========================================")
print("100-PAGE PDF CREATED")
print("==========================================")

print("Rule:", RULE_NO)
print("Pages:", 100)
print("Grid per page:", "300 × 300")
print("Output:", output_file)
# Out:
# Loaded: CA_Snapshots_256/Rule_196.npy
# Shape: (100, 300, 300)
#
# ==========================================
# 100-PAGE PDF CREATED
# ==========================================
# Rule: 196
# Pages: 100
# Grid per page: 300 × 300
# Output: Rule_196_100_Steps.pdf
